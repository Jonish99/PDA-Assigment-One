# %% [markdown]
# #Numpy random package
#
# ###
# Offical Documentation
# https://numpy.org/doc/stable/reference/random/index.html

# %%
#Efficent Numerical Arrays
import numpy as np
#Plotting
import matplotlib.pyplot as plt

# %%
#change default style [5]
plt.style.use('fivethirtyeight') #ggplot

#change defaul plot size [4]
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# <br>
# ## Numpy.random.normal
#
# https://numpy.org/doc/stable/reference/random/index.html

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 1000)

# %%
# view first 10 s
s[:10]
# Out:
# array([ 0.04114778,  0.08873181,  0.09717658,  0.02695708, -0.05273239,
#         0.03416478, -0.016025  , -0.03803714,  0.04535373,  0.02877527])

# %%
abs(mu - np.mean(s))
# Out:
# 0.002297397774225003

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0034059346011188762

# %%
count, bins, ignored = plt.hist(s, 30, density=True)
f=1/(sigma * np.sqrt(2 * np.pi)) * np.exp(-(bins - mu)**2/(2 * sigma**2))
plt.plot(bins, f, linewidth=2)
plt.show()

# %% [markdown]
# ## References
# [1] https://numpy.org/doc/stable/reference/random/index.html
#
# [2] https://realpython.com/numpy-tutorial/
#
# [3] https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html
#
# [4] https://stackoverflow.com/questions/36367986/how-to-make-inline-plots-in-jupyter-notebook-larger
#
# [5] https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %% [markdown]
# ***
# ## End
